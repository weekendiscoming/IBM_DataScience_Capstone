# %% [markdown]
# This notebook will be used for the IBM Data Science Professional Course's capstone project.

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Capstone Project Course")
# Out:
# Capstone Project Course
